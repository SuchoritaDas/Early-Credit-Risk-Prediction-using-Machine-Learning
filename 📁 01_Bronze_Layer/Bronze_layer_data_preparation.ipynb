# %%
df = spark.read.csv(
    "/Volumes/workspace/finance/credit_risk_raw_data",
    header=True,
    inferSchema=True
)

display(df)

# %%
df.write.format("delta").mode("overwrite").saveAsTable("bronze_credit_risk")
display(spark.sql("DESCRIBE EXTENDED bronze_credit_risk"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(spark.sql("SELECT * FROM bronze_credit_risk LIMIT 10"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.write.format("delta") \
  .mode("overwrite") \
  .saveAsTable("finance.bronze_credit_risk")

# %%
# %sql
DROP TABLE default.bronze_credit_risk;
